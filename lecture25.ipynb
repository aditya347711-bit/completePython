# %% [markdown]
# # lecture25 - Dictionary in python - part3

# %% [markdown]
# # membership testing

# %%
person = {
    'name': 'aditya',
    'age': 21,
    'city': 'dhanbad'
}

# %%
print('city' in person)
# Out:
# True

# %% [markdown]
# # nested dictionaries

# %%
employees = {
    'emp1': {'name':'anil','age':21,'city':'dhanbad'},
    'emp2': {'name':'aditya','age':22,'city':'garwah'}
}

# %%
print(employees['emp1'])
# Out:
# {'name': 'anil', 'age': 21, 'city': 'dhanbad'}

# %% [markdown]
# # pratice question

# %%
book_ratings = {
    'python programing': 4.5,
    'machine learning basics':4.8,
    'data science handbook':4.2
}
if 'python programing' in book_ratings:
    print("found")
else:
    print("not found")

titles = list(book_ratings.keys())
print(titles)
# Out:
# found
# ['python programing', 'machine learning basics', 'data science handbook']

# %% [markdown]
# # practice question

# %%
fruit_stock = {
    'apple': 10,
    'banana': 15,
    'orange':8,
    'grape':20
}

for fruit in fruit_stock:
    print("fruit:", fruit,"stock",fruit_stock[fruit])
# Out:
# fruit: apple stock 10
# fruit: banana stock 15
# fruit: orange stock 8
# fruit: grape stock 20
