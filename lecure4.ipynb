# %%
# Lec 4
built in function

# %% [markdown]
# # Float function

# %%
num_int = 10
print(type(num_int))
a = float(num_int)
print(a)
print(type(a))

# %%
a = "3.14"
print(type(a))
b = float(a)
print(b)
print(type(b))
# Out:
# <class 'str'>
# 3.14
# <class 'float'>

# %% [markdown]
# # int function

# %%
a = 5.69465
print(type(a))
b = int(a)
print (b)
print(type(b))
# Out:
# <class 'float'>
# 5
# <class 'int'>

# %%
a = "22"
print(type(a))
b = int(a)
print(b)
print(type(b))
# Out:
# <class 'str'>
# 22
# <class 'int'>

# %% [markdown]
# # str function

# %%
a = 10
print(type(a))
b = str(a)
print(b)
print(type(b))
c = "2"
print(b+c)
print(a+2)
# Out:
# <class 'int'>
# 10
# <class 'str'>
# 102
# 12

# %%
x = 5.645482
print(type(x))
y = str(x)
print(y)
print(type(y))
# Out:
# <class 'float'>
# 5.645482
# <class 'str'>

# %% [markdown]
#  # complex function

# %%
comp = complex(2,3)
print(comp)
# Out:
# (2+3j)

# %%
y = complex(6,89)
print(y)
# Out:
# (6+89j)

# %% [markdown]
# # abs function

# %%
x = -23
print(abs(x))
# Out:
# 23

# %%
y = -2.5647646
print(abs(y))
# Out:
# 2.5647646

# %%
z =  -3+4j
print(abs(z))
# Out:
# 5.0

# %% [markdown]
#  # len function

# %%
a = "hello i am aditya"
print(len(a))
# Out:
# 17

# %%
b = "cat dog"
print(len(b))
# Out:
# 7

# %%
c = [12,25,7,8,9,2]
print(len(c))
# Out:
# 6

# %% [markdown]
# # practice question

# %%
In a game application, the player's score is stored as a floating-point number. However, for leaderboard display, you need to convert the score to an integer. How would you use the int() function to convert the player's score from floating-point to integer format? pls solve this with code, player score 1234.56

# %%
player_score = 1234.56
print("the player score is", int(player_score))
# Out:
# the player score is 1234

# %%
In a customer relationship management (CRM) system for a retail company, you have a database containing customer records. How would you use the len() function to find the total number of customers in the database, allowing the company to track its customer base?
customer_database = [
]
(1, 'John Doe', 'john@example.com'),
(2, 'Jane Smith', 'jane@example.com'),
(3, 'Alice Johnson', 'alice@example.com'),

# %%
customer_database = [
(1, 'John Doe', 'john@example.com'),
(2, 'Jane Smith', 'jane@example.com'),
(3, 'Alice Johnson', 'alice@example.com'),]
print("the total number of customers in the database is", len(customer_database))
# Out:
# the total number of customers in the database is 3

# %%
You're developing a financial application that calculates simple interest. The principal amount is 250000 Rs, the interest rate is 9.34567%, and the time period is 3 years. Calculate the Simple Interest (SI), and the final value should be an integer.

# %%
p = 250000
r = 9.34567
t = 3
SI = ((p*r*t)/100)
print("the simple insterst is", SI)
print("the integer value is",int (SI))
# Out:
# the simple insterst is 70092.525
# the integer value is 70092

# %%
You're working at a travel company, responsible for managing passenger information. Due to a technical glitch in the booking system, some passengers ages were mistakenly recorded as negative values. However, age cannot be negative, and it's essential to correct this data inconsistency before further analysis or reporting.
which function you will use to correct the ages of all passengers in the dataset where negative ages were recorded due to a technical glitch?

# %%
abs function
