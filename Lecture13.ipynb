# %% [markdown]
# # Lecture 13

# %% [markdown]
# # string - parts 2

# %% [markdown]
# # length - method

# %%
s = "theiscale"
print(len(s))
# Out:
# 9

# %%
s = " "
print(len(s))
# Out:
# 1

# %%
s = "  "
print(len(s))
# Out:
# 2

# %%
s = "hello\nworld"
print(s)
print(len(s))
# Out:
# hello
# world
# 11

# %%
s = "hello@world"
print(s)
print(len(s))
# Out:
# hello@world
# 11

# %%
s = """hello
world"""
print(s)
print(len(s))
# Out:
# hello
# world
# 11

# %%
a = "data science is best carrier path for the student"
print(len(a))
# Out:
# 49

# %% [markdown]
# # python - modify strings

# %% [markdown]
# # upper method

# %%
s = "this is the iscale"
print(s.upper())
# Out:
# THIS IS THE ISCALE

# %%
s = "this IS the iscale"
print(s.upper())
# Out:
# THIS IS THE ISCALE

# %%
s = "this is the iscale 123"
print(s.upper())
# Out:
# THIS IS THE ISCALE 123

# %% [markdown]
# # lower method

# %%
a = "i am aditya"
print(a.upper())
b = "THIS IS MY PYTHON CLASS"
print(b.lower())
# Out:
# I AM ADITYA
# this is my python class

# %%
b = "Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or extrapolate knowledge from potentially noisy, structured, or unstructured data.[2]"
print(b.upper())
print(b.lower())
# Out:
# DATA SCIENCE IS AN INTERDISCIPLINARY ACADEMIC FIELD[1] THAT USES STATISTICS, SCIENTIFIC COMPUTING, SCIENTIFIC METHODS, PROCESSING, SCIENTIFIC VISUALIZATION, ALGORITHMS AND SYSTEMS TO EXTRACT OR EXTRAPOLATE KNOWLEDGE FROM POTENTIALLY NOISY, STRUCTURED, OR UNSTRUCTURED DATA.[2]
# data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or extrapolate knowledge from potentially noisy, structured, or unstructured data.[2]

# %% [markdown]
# # string concatenation

# %%
a = "hello"
b = "world"
print(a + " " + b)
# Out:
# hello world

# %%
a = "data"
print(a*5)
# Out:
# datadatadatadatadata

# %% [markdown]
# # replace method

# %%
text = "hello friend, i am learning python"
rep = text.replace("python", "data science")
print(rep)
# Out:
# hello friend, i am learning data science

# %%
text  = "Data science is the study of data to extract meaningful insights for business. It is a multidisciplinary approach that combines principles and practices from the fields of mathematics, statistics, artificial intelligence, and computer engineering to analyze large amounts of data. This analysis helps data scientists to ask and answer questions like what happened, why it happened, what will happen, and what can be done with the results."
rep = text.replace("Data science", "python")
print(rep)
# Out:
# python is the study of data to extract meaningful insights for business. It is a multidisciplinary approach that combines principles and practices from the fields of mathematics, statistics, artificial intelligence, and computer engineering to analyze large amounts of data. This analysis helps data scientists to ask and answer questions like what happened, why it happened, what will happen, and what can be done with the results.

# %% [markdown]
# # index method

# %%
a = "i want to learn"
print(a.index("to"))
# Out:
# 7

# %%
b = "python is the study of data to extract meaningful insights for business"
print(b.index("business"))
# Out:
# 63

# %% [markdown]
# # find

# %%
a = "python is great"
b = a.find("g")
print(b)
# Out:
# 10

# %% [markdown]
# # python part1 complete done
