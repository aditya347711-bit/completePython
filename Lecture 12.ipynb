# %% [markdown]
# # lecture 12
# # strings in python - part 1
# # creating strings in python

# %%
a = 'learners'
print (a)
print(type(a))
# Out:
# learners
# <class 'str'>

# %%
b = "students"
print(b)
print(type(b))
# Out:
# students
# <class 'str'>

# %%
str = "I am aditya \nthis is my first class"
print(str)
# Out:
# I am aditya
# this is my first class

# %% [markdown]
# # multiline strings

# %%
a = """data science is the best carrier 
field as an learner ids most popular in day by day 
this is helpful to company 
as an analyzind any type of data is helps to grow up your bussines"""
print(a)
# Out:
# data science is the best carrier
# field as an learner ids most popular in day by day
# this is helpful to company
# as an analyzind any type of data is helps to grow up your bussines

# %% [markdown]
# # indexing of strings

# %%
a = "hello dear learners"
print(a[0])
print(a[1])
print(a[2])
print(a[3])
print(a[4])
print(a[5])
print(a[6])
# Out:
# h
# e
# l
# l
# o
#
# d

# %%
a = "hello dear learners"
print(a[-1])
print(a[-2])
print(a[-3])
print(a[-4])
print(a[-5])
print(a[-6])
# Out:
# s
# r
# e
# n
# r
# a

# %%
b = "i am learning data science"
print(b[-1],b[-2],b[-3],b[-4])
# Out:
# e c n e

# %% [markdown]
# # slicing

# %%
a = "i am aditya"
print(a[0:11])
# Out:
# i am aditya

# %%
a = "i am aditya"
print(a[0:7])
# Out:
# i am ad

# %%
a = "hello i am aditya"
print(a[:])
# Out:
# hello i am aditya

# %% [markdown]
# # slicing with jump

# %%
a = "hello i am aditya"
print(a[0:5:2])
# Out:
# hlo

# %%
a = "i am learning datascience"
print(a[0:10:3])
# Out:
# imen

# %%
a = "i am learning datascience"
print(a[: : 2])
# Out:
# ia erigdtsine

# %% [markdown]
# # negative slicing

# %%
a = "i am learning datascience"
print(a[-16:-1])
# Out:
# ning datascienc

# %%
a = "i am learning datascience"
print(a[-18:-1:2])
# Out:
# ann aacec

# %% [markdown]
# # practice questin

# %%
def extract_date_parts(date_string):
    year = int(date_string[0:4])
    month = int(date_string[5:7])
    day = int(date_string[8:])
    return (year, month, day)

# %%
extract_date_parts("2024-05-28")
# Out:
# (2024, 5, 28)

# %%
write a program to reverse the string "honesty is the best poicy"

# %%
str = "honesty is the best policy"
print(str[::-1])
# Out:
# ycilop tseb eht si ytsenoh

# %%
write an python function that takes a string
as input and returns the substring
from the 3rd to the 8th character

"Data Science"
"hello world, i am learning python"
"All the best"

# %%
substring = "data science"
print(substring[3:8])
# Out:
# a sci

# %%
s = "Artificial"
print(s[:-4])
# Out:
# Artifi
