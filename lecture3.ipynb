# %% [markdown]
# # lecture 3
# # Arithmetic operator
# # adition

# %%
a = 1
b = 3
print(a+b)
# Out:
# 4

# %%
x = 1.5 
y = 2.3
print(x+y)
# Out:
# 3.8

# %%
a1 = "hello"
b1 = "aditya"
print(a1 + b1)
# Out:
# helloaditya

# %%
a1 = "hello"
b1 = "aditya"
print(a1 + " " + b1)
# Out:
# hello aditya

# %%
x1 = 2+3j
y1 = 1+5j
print(x1 + y1)
# Out:
# (3+8j)

# %%
w1 = -6
w2 = 3
print(w1+w2)
# Out:
# -3

# %% [markdown]
# # subtraction operator

# %%
num1 = 8
num2 = 4
print(num1 - num2)
# Out:
# 4

# %%
a1 = 5.67
b1 = 2.34
print(a1 - b1)
# Out:
# 3.33

# %%
a5 = "hello"
a6 = "student"
print(a5 - a6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 a5 = "hello"
#       2 a6 = "student"
# ----> 3 print(a5 - a6)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
a6 = 5+9j
b6 = 3+5j
print(a6 - b6)
# Out:
# (2+4j)

# %% [markdown]
# # multiplication

# %%
n = 3
b = 5 
print(n*b)
# Out:
# 15

# %%
n = 3.56
b = 5.85
print(n*b)
# Out:
# 20.826

# %%
str = "hello"
print(str*5)
# Out:
# hellohellohellohellohello

# %%
str1 = "hello"
str2 = "world"
print(str1*str2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 str1 = "hello"
#       2 str2 = "world"
# ----> 3 print(str1*str2)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
str1  = "hello i am aditya "
print(str1*5)
# Out:
# hello i am aditya hello i am aditya hello i am aditya hello i am aditya hello i am aditya

# %%
a1 = 2+3j
b1 = 3+4j
print(a1*b1)
# Out:
# (-6+17j)

# %% [markdown]
# # Divison

# %%
a = 15
b = 3
print(a/b)
# Out:
# 5.0

# %%
a1  = 154.45879213
b1 = 23.5427698
print(a1/b1)
# Out:
# 6.5607740058690975

# %%
com1 = 2+3j
com2 = 1+2j
print(com1/com2)
# Out:
# (1.6-0.2j)

# %%
str1 = "hello"
str2 = "stdudent"
print(str1/str2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 str1 = "hello"
#       2 str2 = "stdudent"
# ----> 3 print(str1/str2)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# # modulus

# %%
print(12%5)
# Out:
# 2

# %%
print(65323565%546)
# Out:
# 125

# %%
a1 = 45.4552556
b1 = 21
print(a1%b1)
# Out:
# 3.455255600000001

# %%
print(12//3)
# Out:
# 4

# %%
a1 = 12.3647
b1 = 4.568
print(a1//b1)
# Out:
# 2.0

# %% [markdown]
# # exponent

# %%
 a = 3
 b = 2
print(a**b)
# Out:
# 9

# %%
w = 60
h = 5
v = h**2
print(w/v)
# Out:
# 2.4

# %%
print(5.25478**3)
# Out:
# 145.09873122151538

# %% [markdown]
# # Boolean operator

# %%
a = True
print(type(a))
# Out:
# <class 'bool'>

# %%
a1 = False
print(type(a1))
# Out:
# <class 'bool'>

# %% [markdown]
# # comparison operator
# In python, comparison operators are used to compare values.These operators return True or false based on wether the comparison is true or false

# %% [markdown]
# equal to ==

# %%
x = 5
y = 5
print(x==y)
# Out:
# True

# %%
x = 6
y = 5
print(x==y)
# Out:
# False

# %% [markdown]
# not equal to !=

# %%
x = 5
y = 3
print(x!=y)
# Out:
# True

# %%
x = 5
y = 5
print(x!=y)
# Out:
# False

# %% [markdown]
# greater than>

# %%
x = 5
y = 13
print(x>y)
# Out:
# False

# %% [markdown]
# less than<

# %%
x = 12
y = 7
print(x<y)
# Out:
# False

# %%
print(10<850)
# Out:
# True

# %% [markdown]
# greater than equal to >=

# %%
x = 5
y = 5
print(x>=y)
# Out:
# True

# %% [markdown]
# less than equal to <=

# %%
x = 5
y = 5
print(x<=y)
# Out:
# True

# %% [markdown]
# # Logical operator

# %%
x = True
y = False
print(x and y)
# Out:
# False

# %%
x = True
y = False 
print (x or y)
# Out:
# True

# %%
x = True
print(not x)
# Out:
# False

# %%
x  = False 
print(not x)
# Out:
# True

# %% [markdown]
# # Question practice 3
# write a python program to calculate the are of circle with a radius of 12 cm.

# %%
# Area of a circle = pi *r2
radius = 12
pi = 3.14
area = pi * (radius**2)
print("area of circle is :", area)
# Out:
# area of circle is : 452.16
