# %% [markdown]
# # lecture 7

# %% [markdown]
# # control flow statement

# %% [markdown]
# # if statement

# %%
i = 10

if i<20:
    print("20is greater than 10")
    print("condition is false")
# Out:
# 20is greater than 10
# condition is false

# %%
temp = float(input("enter the temperature"))
if temp<15:
    print("temperatrure is not convinent")
if temp<28:
    print("temperature is convinent")
# Out:
# enter the temperature 17
# temperature is convinent

# %% [markdown]
# # if else statement

# %% [markdown]
# write a program to check whether a person is eligible for voting or not

# %%
age = int(input("enter your age"))
if age>18:
    print("you are eligible to vote")
else:
    print("you are not eligible to vote")
# Out:
# enter your age 20
# you are eligible to vote

# %%
age = int(input("enter your age"))
if age>18:
    print("you are eligible to vote")
else:
    print("you are not eligible to vote")
# Out:
# enter your age 12
# you are not eligible to vote

# %% [markdown]
# # if elif else

# %%
a = input("enter the city")
if a == "mumbai":
    print("the famous monument is a getway of india")
elif a == "kolkata":
    print("the famous monument is victoria memorial")
elif a == "chennai":
    print("the famous monument is marina beach")
elif a == "banglore":
    print("the famous monument is botnical garden")
elif a == "pune":
    print("the famous monument is shaniwar vada")
else:
    print("no record found")
# Out:
# enter the city kolkata
# the famous monument is victoria memorial

# %%
a = input("enter the city")
if a == "mumbai":
    print("the famous monument is a getway of india")
elif a == "kolkata":
    print("the famous monument is victoria memorial")
elif a == "chennai":
    print("the famous monument is marina beach")
elif a == "banglore":
    print("the famous monument is botnical garden")
elif a == "pune":
    print("the famous monument is shaniwar vada")
else:
    print("no record found")
# Out:
# enter the city delhi
# no record found

# %%
a = input("enter the car name")
if a == "creta":
    print("creta is good car")
elif a == "maruti":
    print("maruti is samallest car")
elif a == "fortuner":
    print("fortuner is luxary car")
elif a == "scorpio":
    print("scorpio is divid car")
# Out:
# enter the car name scorpio
# scorpio is divid car

# %%
a = input("enter is the flower name")
if a == "sunflower":
    print("sunflower is beautyful")
if a == "lily":
    print("lily is attractive")
if a ==
