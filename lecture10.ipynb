# %% [markdown]
# # Lecture 10
# user defined functions

# %% [markdown]
# # creating and calling a function

# %%
def my_function():
    print("hello i am aditya")

# %%
my_function()
# Out:
# hello i am aditya

# %%
def my_address():
    print("good morning baby")

# %%
my_address()
# Out:
# good morning baby

# %%
def my_name():
    print("hello everyone my name is aditya sharma this is my python my first class")

# %%
my_name()
# Out:
# hello everyone my name is aditya sharma this is my python my first class

# %%
def details_bill():
    print("the last date of the bill payment is on next week sunday")
    print("after deadline, you need to pay rs 1000 as a fine")
    print("pay your bill soon")

# %%
for i in range(3):
    a = input("enter your name")
    b = int(input("enter the unit of electricity you have consumed"))
    bill = b*10
    print("total amount of bill you need to pay is", bill)
    details_bill()
# Out:
# enter your name aditya sharma
# enter the unit of electricity you have consumed 500
# total amount of bill you need to pay is 5000
# the last date of the bill payment is on next week sunday
# after deadline, you need to pay rs 1000 as a fine
# pay your bill soon
# enter your name ankit
# enter the unit of electricity you have consumed 200
# total amount of bill you need to pay is 2000
# the last date of the bill payment is on next week sunday
# after deadline, you need to pay rs 1000 as a fine
# pay your bill soon
# enter your name anil
# enter the unit of electricity you have consumed 300
# total amount of bill you need to pay is 3000
# the last date of the bill payment is on next week sunday
# after deadline, you need to pay rs 1000 as a fine
# pay your bill soon

# %% [markdown]
# # Arguments

# %% [markdown]
# # create a function, which checks the number is even or odd

# %%
def check_even_odd(number):
    if number%2==0:
        print("the number is even")
    else:
        print("the number is odd")

# %%
check_even_odd(24)
# Out:
# the number is even

# %%
check_even_odd(27)
# Out:
# the number is odd

# %% [markdown]
# # 2 arguments

# %%
def my_name(fname, lname):
    print(fname + " " + lname)

# %%
my_name("aditya","sharma")
# Out:
# aditya sharma

# %%
def calculate_exam_statistics(exam_score):
    num_students = len(exam_score)
    average_score = sum(exam_score)/num_students
    highest_score = max(exam_score)
    lowest_score = min(exam_score)

    num_passed = 0
    for score in exam_score:
        if score>= 80:
            num_passed  = num_passed +1
    num_failed = num_students - num_passed
    return average_score, highest_score, lowest_score, num_passed, num_failed


exam_score = [85, 92, 78, 90, 88, 95, 82, 79, 87, 91]

average_score, highest_score, lowest_score, num_passed, num_failed = calculate_exam_statistics(exam_score)

print("the average score is", average_score)
print("the highest score is", highest_score)
print("the lowest score is", lowest_score)
print("the number of students passed is", num_passed)
print("the number of students fail is", num_failed)
# Out:
# the average score is 86.7
# the highest score is 95
# the lowest score is 78
# the number of students passed is 8
# the number of students fail is 2
