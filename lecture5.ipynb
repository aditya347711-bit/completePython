# %% [markdown]
# # Lecture 5
# # built in function part 2
# # Bin function

# %%
The bin() function in Python is used to
convert an integer number to its
binary representation as a string prefixed with 'Øb'.
It takes an integer as an argument
and returns its binary representation.

# %%
binary_rep = bin(10)
print(binary_rep)
# Out:
# 0b1010

# %%
 z = bin(200)
print(z)
# Out:
# 0b11001000

# %%
c = bin(56641164625554645977)
print(c)
# Out:
# 0b110001001000001101110101110010000100010010100110110010001111011001

# %% [markdown]
# # sum function

# %%
the sum () function in python is used to calculate the sum of elements in an iterable, such as lists, tuples, and other iterable objects.

# %%
my_list = [7,8,9,5,8,629,28]
a = sum(my_list)
print(a)
# Out:
# 694

# %%
my_list = [10.4,52.4,75.5]
print(sum(my_list))
# Out:
# 138.3

# %%
str = ['swati', 'nishant']
print(sum(str))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 str = ['swati', 'nishant']
# ----> 2 print(sum(str))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = [ 1,2,3,4,5]
starting_value = 10
total = sum(a,starting_value)
print(total)
# Out:
# 25

# %% [markdown]
# # eval function
# eval() : Evalutes a python expression stored in string

# %%
x = 10
y = 5 
expression = "x+y*2"
print(eval(expression))
# Out:
# 20

# %%
exp = "5/2+3.5"
print(eval(exp))
print(type(exp))
# Out:
# 6.0
# <class 'str'>

# %%
exp1 = "234*25+63-98/2"
print(eval(exp1))
# Out:
# 5864.0

# %%
x = 5
y = 2.5
z = 32
exp = "x+y-z*23/5-9*3"
print(eval(exp))
# Out:
# -166.7

# %% [markdown]
# # chr function
# extra for me

# %%
print(chr(65))
# Out:
# A

# %% [markdown]
# # help
# the python help function is used to display the documantation of modules, function, class, keywords, etc.

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %%
help(float)
# Out:
# Help on class float in module builtins:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating-point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(self, /)
#  |      Return the ceiling as an Integral.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(self, /)
#  |      Return the floor as an Integral.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getnewargs__(self, /)
#  |
# ...

# %% [markdown]
# # input function

# %%
name = input("enter your name")
print("name enterd by user is", name)
print(type(name))
# Out:
# enter your name aditya sharma
# name enterd by user is aditya sharma
# <class 'str'>

# %%
age = input("enter your age pls")
print("age of user is", age)
print(type(age))
# Out:
# enter your age pls 20
# age of user is 20
# <class 'str'>

# %% [markdown]
# # practice question

# %% [markdown]
# # Question 1

# %%
Get two number from the user from the user and calculate their sum

# %%
num1 = int(input("enter the first name"))
num2 = int(input("enter the second name"))
sum = num1 + num2
print(sum)
# Out:
# enter the first name 3
# enter the second name 5
# 8

# %% [markdown]
# # question 2

# %%
As part of your role in a data-driven project, you need to take input from the user for their age, weight, and height. However, there's an issue: the user has entered their age as a negative number. You need to correct the age of the user, and after correcting the age, calculate their Basal Metabolic Rate (BMR) using the Harris-Benedict equation for men. Ensure that the final answer of BMR is an integer.
Basal Metabolic Rate (BMR):
Formula (Harris-Benedict equation for men):
BMR = 88.362 + (13.397 * weight in kg) + (4.799 height in cm) - (5.677 * age in years)

# %%
age = int(input("enter your age"))
weight = int(input("enter your age"))
height = float(input("enter your height"))
correct_age = abs(age)
print("the correct age of user is" , correct_age)
BMR = "88.362 + (13.397*weight) + (4.799*height)-(5.677*age)"
bmr = eval(BMR)
print("the BMR of the patient is", int(bmr))
# Out:
# enter your age -45
# enter your age 85
# enter your height 5.6
# the correct age of user is 45
# the BMR of the patient is 1509

# %% [markdown]
# # homework

# %% [markdown]
# # question 3

# %%
write a python code for hostel students, ask them to mention their course name and age. for 5 students and calculate their avg age.
