# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# we can download csv file from kaggle as houseprediction
dataset =pd.read_csv("C:\\Users\\ADITYA\\Downloads\\Comp1_set.csv",)
dataset.head(50)
# Out:
#     Unnamed: 0                Apartment  \
# 0            0          2 BHK Apartment
# 1            1          2 BHK Apartment
# 2            2  2 BHK Independent Floor
# 3            3          1 BHK Apartment
# 4            4          2 BHK Apartment
# 5            5          3 BHK Apartment
# 6            6          3 BHK Apartment
# 7            7  3 BHK Independent House
# 8            8          2 BHK Apartment
# 9            9          2 BHK Apartment
# 10          10  6 BHK Independent House
# 11          11          2 BHK Apartment
# 12          12          3 BHK Apartment
# 13          13          2 BHK Apartment
# 14          14         Residential Plot
# 15          15  4 BHK Independent House
# 16          16          3 BHK Apartment
# 17          17          3 BHK Apartment
# 18          18              7 BHK Villa
# 19          19          2 BHK Apartment
# 20          20          2 BHK Apartment
# 21          21          2 BHK Apartment
# 22          22          3 BHK Apartment
# 23          23          2 BHK Apartment
# 24          24          2 BHK Apartment
# 25          25          2 BHK Apartment
# 26          26         Residential Plot
# 27          27          3 BHK Apartment
# 28          28          2 BHK Apartment
# 29          29  2 BHK Independent House
# 30          30          2 BHK Apartment
# 31          31          2 BHK Apartment
# 32          32  2 BHK Independent House
# 33          33  2 BHK Independent House
# 34          34          3 BHK Apartment
# 35          35          2 BHK Apartment
# 36          36          2 BHK Apartment
# 37          37          2 BHK Apartment
# 38          38          2 BHK Apartment
# 39          39          2 BHK Apartment
# 40          40          1 BHK Apartment
# 41          41          2 BHK Apartment
# 42          42          3 BHK Apartment
# 43          43          2 BHK Apartment
# 44          44          2 BHK Apartment
# 45          45          2 BHK Apartment
# 46          46          3 BHK Apartment
# 47          47          2 BHK Apartment
# 48          48          3 BHK Apartment
# 49          49         Residential Plot
#
#                                      Society                 Location  \
# 0                                        NaN                 Baruipur
# 1                                        NaN                    Garia
# 2                                        NaN                Baranagar
# 3                                        NaN                    Garia
# 4                                        NaN                 Dhakuria
# 5                           Rajwada Emeralds              Narendrapur
# 6                                        NaN                Bramhapur
# 7                                        NaN            south dum dum
# 8                                        NaN        Uttarpara Kotrung
# 9                                        NaN                 New Town
# 10                                       NaN               Tollygunge
# 11                                       NaN                    Garia
# 12                                       NaN                 Jadavpur
# 13                                       NaN                   Patuli
# 14                          Debrupayan Nagar                  Sodepur
# 15                                       NaN                 Gariahat
# 16                                       NaN   Howrah Railway Station
# 17                                       NaN                Serampore
# 18                                       NaN              Budge Budge
# 19                                       NaN             Garden Reach
# 20                                       NaN                   Behala
# 21                                       NaN                   Behala
# 22                       Sheltercon Arunoday                  Nayabad
# 23    Reputed Builder Bally Ganga Apratments                    Bally
# 24              Reputed Builder Dumdum plaza            south dum dum
# 25                         Avidipta Avidipta               Santoshpur
# 26                                       NaN             Jodhpur Park
# 27                              Srijan Ozone              Narendrapur
# 28                      DTC Southern Heights                     Joka
# 29                                       NaN              Madhyamgram
# 30                                       NaN                 Kaikhali
# 31                          SK Royal Complex        Uttarpara Kotrung
# 32                                       NaN                  Barasat
# 33                                       NaN                  Sarsuna
# 34                                       NaN              Barrackpore
# 35                                       NaN                    Kasba
# 36                                       NaN  Barisha Purba Para Road
# 37                   Sweet Sinjini Apartment                 Rajarhat
# 38                                       NaN               Tollygunge
# 39                                       NaN                   Birati
# 40  Srijan Star Srijan Swapno Puron Phase II                   Amtala
# 41  Srijan Star Srijan Swapno Puron Phase II                   Amtala
# 42  Srijan Star Srijan Swapno Puron Phase II                   Amtala
# 43  Srijan Star Srijan Swapno Puron Phase II                   Amtala
# 44                           Siddha Suburbia              Narendrapur
# 45                              Silver Vista                Lake Town
# 46                              Silver Vista                Lake Town
# 47                                       NaN                  Sarsuna
# 48                      Citadel Silver Space              Madhyamgram
# 49                               Amtala City                   Amtala
#
#        Price      Price/sqft  SqftArea Construction_Status        Year's Old  \
# 0       32 L   3,265 / sq ft       980       Ready to move               NaN
# 1       36 L   4,645 / sq ft       775       Ready to move               NaN
# 2       24 L   3,243 / sq ft       740       Ready to move               NaN
# 3       30 L   5,859 / sq ft       512       Ready to move               NaN
# 4    1.14 Cr  10,654 / sq ft      1070       Ready to move               NaN
# 5       68 L   5,151 / sq ft      1320       Ready to move   4 - 5 years old
# 6       35 L   2,536 / sq ft      1380       Ready to move   6 - 7 years old
# 7       85 L   4,250 / sq ft      2000       Ready to move   7 - 8 years old
# 8       20 L   2,702 / sq ft       740       Ready to move               NaN
# 9       35 L   4,046 / sq ft       865       Ready to move               NaN
# 10      75 L   3,000 / sq ft      2500       Ready to move               NaN
# 11      41 L   4,480 / sq ft       915       Ready to move               NaN
# 12      55 L   4,435 / sq ft      1240       Ready to move               NaN
# 13      50 L   5,452 / sq ft       917       Ready to move               NaN
# 14      13 L     902 / sq ft      1440              Resale   3 - 4 years old
# 15    2.5 Cr  10,000 / sq ft      2500       Ready to move               NaN
# 16   1.05 Cr   7,425 / sq ft      1414       Ready to move   6 - 7 years old
# 17      27 L   2,518 / sq ft      1072       Ready to move               NaN
# 18      3 Cr   7,894 / sq ft      3800       Ready to move               NaN
# 19   15.55 L   2,828 / sq ft       550       Ready to move   6 - 7 years old
# 20      38 L   4,935 / sq ft       770       Ready to move               NaN
# 21      22 L   3,098 / sq ft       710       Ready to move               NaN
# 22      58 L   4,531 / sq ft      1280       Ready to move               NaN
# 23      45 L   4,090 / sq ft      1100       Ready to move   4 - 5 years old
# 24      26 L   4,727 / sq ft       550       Ready to move   4 - 5 years old
# 25   1.35 Cr  10,522 / sq ft      1283       Ready to move   7 - 8 years old
# 26      85 L   5,862 / sq ft      1450              Resale               NaN
# 27    1.8 Cr  11,271 / sq ft      1597       Ready to move    0 - 1 year old
# 28      56 L   5,957 / sq ft       940       Ready to move               NaN
# 29      45 L   3,202 / sq ft      1405       Ready to move               NaN
# 30      32 L   3,575 / sq ft       895       Ready to move               NaN
# 31      32 L   3,516 / sq ft       910       Ready to move   7 - 8 years old
# 32      16 L   1,111 / sq ft      1440       Ready to move               NaN
# 33      40 L   2,247 / sq ft      1780       Ready to move               NaN
# 34      34 L   3,683 / sq ft       923       Ready to move               NaN
# 35      32 L   4,210 / sq ft       760       Ready to move               NaN
# 36      30 L   3,448 / sq ft       870       Ready to move   6 - 7 years old
# 37      26 L   3,421 / sq ft       760       Ready to move  9 - 10 years old
# 38      32 L   4,481 / sq ft       714       Ready to move               NaN
# 39      35 L   4,861 / sq ft       720       Ready to move               NaN
# 40    16.1 L   3,642 / sq ft       442       Ready to move        1 year old
# 41   22.67 L   3,638 / sq ft       623       Ready to move        1 year old
# 42    34.1 L   3,616 / sq ft       943       Ready to move        1 year old
# 43    19.1 L   3,687 / sq ft       518       Ready to move        1 year old
# 44      55 L   5,308 / sq ft      1036       Ready to move   2 - 3 years old
# 45      63 L   5,250 / sq ft      1200       Ready to move    0 - 1 year old
# 46    73.5 L   5,250 / sq ft      1400       Ready to move    0 - 1 year old
# 47      23 L   3,066 / sq ft       750       Ready to move               NaN
# 48      68 L   5,070 / sq ft      1341       Ready to move   5 - 6 years old
# 49    9.99 L     555 / sq ft      1800                 New    0 - 1 year old
#
#       bathrooms type of property
# 0   2 Bathrooms          Resale
# 1   2 Bathrooms          Resale
# 2   1 Bathrooms          Resale
# 3   1 Bathrooms          Resale
# 4   2 Bathrooms          Resale
# 5   2 Bathrooms          Resale
# 6   2 Bathrooms          Resale
# 7   2 Bathrooms          Resale
# 8   1 Bathrooms          Resale
# 9   2 Bathrooms          Resale
# 10  6 Bathrooms          Resale
# 11  2 Bathrooms          Resale
# 12  3 Bathrooms          Resale
# 13  2 Bathrooms          Resale
# 14          NaN              NaN
# 15  5 Bathrooms          Resale
# 16  2 Bathrooms          Resale
# 17  3 Bathrooms          Resale
# 18  5 Bathrooms          Resale
# 19  1 Bathrooms          Resale
# 20  1 Bathrooms          Resale
# 21  2 Bathrooms          Resale
# 22  2 Bathrooms          Resale
# 23  2 Bathrooms          Resale
# 24  1 Bathrooms          Resale
# 25  2 Bathrooms          Resale
# 26          NaN              NaN
# 27  3 Bathrooms          Resale
# 28  2 Bathrooms          Resale
# 29  2 Bathrooms          Resale
# 30  2 Bathrooms          Resale
# 31  2 Bathrooms          Resale
# 32  2 Bathrooms          Resale
# 33  2 Bathrooms          Resale
# 34  2 Bathrooms          Resale
# 35  1 Bathrooms          Resale
# 36  2 Bathrooms          Resale
# 37  2 Bathrooms          Resale
# 38  2 Bathrooms          Resale
# 39  2 Bathrooms          Resale
# 40          NaN             New
# 41  2 Bathrooms             New
# 42  2 Bathrooms             New
# 43  1 Bathrooms             New
# 44  2 Bathrooms             New
# 45          NaN             New
# 46  3 Bathrooms             New
# 47  2 Bathrooms          Resale
# 48  2 Bathrooms          Resale
# 49          NaN              NaN

# %%
dataset.shape
# Out:
# (340, 11)

# %% [markdown]
# # step2 :Data preprocessing

# %%
obj = (dataset.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Categorical variables:", len(object_cols))

int_ = (dataset.dtypes == 'int')
num_cols = list(int_[int_].index)
print("Integer variables:", len(num_cols))

fl = (dataset.dtypes == 'float')
fl_cols = list(fl[f1].index)
print("Float variables:", len(fl_cols))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 obj = (dataset.dtypes == 'object')
#       2 object_cols = list(obj[obj].index)
#       3 print("Categorical variables:", len(object_cols))
#
# NameError: name 'dataset' is not defined

# %% [markdown]
# # Step 3: Exploratory Data Analysis

# %%
numerical_dataset = dataset.select_dtypes(include=['number'])

plt.figure(figsize=(12, 6))
sns.heatmap(numerical_dataset.corr(),
cmap = 'BrBG',
fmt = '.2f% ',
linewidths = 2,
annot = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 numerical_dataset = dataset.select_dtypes(include=['number'])
#       3 plt.figure(figsize=(12, 6))
#       4 sns.heatmap(numerical_dataset.corr(),
#       5 cmap = 'BrBG',
#       6 fmt = '.2f% ',
#       7 linewidths = 2,
#       8 annot = True)
#
# NameError: name 'dataset' is not defined
